# %% [markdown]
# ## Polytope Climate-DT example notebook
#
# This notebook shows how to use earthkit-data and earthkit-plots to pull destination-earth data from LUMI and plot it using earthkit-plots. Specifically this notebook shows how to do server side interpolation to a healpix grid.
#
# Before running the notebook you need to set up your credentials. See the main readme of this repository for different ways to do this or use the following cells to authenticate.
#
# You will need to generate your credentials using the desp-authentication.py script.
#
# This can be run as follows:

# %%
# %%capture cap
# %run ../../desp-authentication.py

# %% [markdown]
# This will generate a token that can then be used by earthkit and polytope.

# %%
output_1 = cap.stdout.split('}\n')
access_token = output_1[-1][0:-1]

# %% [markdown]
# # Requirements
# To run this notebook install the following:
# * pip install earthkit-data
# * pip install earthkit-plots
# * pip install earthkit-regrid  (Optional for spectral variables)
# * pip install cf-units         (Optional for unit conversion in maps)
#
# If you do not have eccodes installed please install eccodes using conda as it is a dependency of earthkit, or install earthkit via conda
#
# * conda install eccodes -c conda-forge
# * conda install earthkit-data -c conda-forge

# %%
import earthkit.data
import earthkit.plots
from earthkit.geo import regrid

# %%
# Defaults to making a live data request. Set to false to use the cached GRIB file instead.
import os

LIVE_REQUEST = os.getenv("LIVE_REQUEST", "true").lower() == "true"
LIVE_REQUEST

# %% [markdown]
# The default interpolation of healpix to healpix grids is ring nested, passing `'grid':'h16'` in your request will result in a healpix ring ordered grid to be returned. One can explicitly asks for nested by adding `n` to the gridspec `'grid' : 'hn16'`. More information can be found on this page: https://polytope.readthedocs.io/en/latest/Service/Full_fields/

# %%
request = {
    "activity": "projections",
    'class': 'd1',
    'dataset': 'climate-dt',
    "date": "20400102",
    'time': "0000",
    'experiment': 'SSP3-7.0',
    'expver': '0001',
    "generation": "2",
    'levtype': 'sfc',
    'model': 'IFS-NEMO',
    'param': '167',
    'realization': '1',
    "resolution": "standard",
    'stream': 'clte',
    # 'grid':'h16', # currently O, F, N, H, HN grids are supported 
    'type': 'fc',
}

# %%
data_file = "../data/climate-dt-earthkit-healpix-interpolate.grib"
if LIVE_REQUEST:
    data = earthkit.data.from_source("polytope", "destination-earth", request, address="polytope.mn5.apps.dte.destination-earth.eu", stream=False)
    data.to_target("file", data_file)
else:
    data = earthkit.data.from_source("file", data_file)

# %%
df = data.to_fieldlist()
df.ls()
# Out:
#   parameter.variable time.valid_datetime time.base_datetime time.step  \
# 0                 2t          2040-01-02         2040-01-02    0 days
#
#    vertical.level        vertical.level_type ensemble.member  \
# 0               2  height_above_ground_level            None
#
#   geography.grid_type
# 0             healpix

# %%
chart = earthkit.plots.Map(extent=[-180, 180, -90, 90])
chart.grid_cells(
    df,
    style="auto",
    units="celsius"
)

chart.title("Temperature")
chart.coastlines()
chart.gridlines()
chart.legend()
chart.show()

# %% [markdown]
# As we can see above, even though the data is stored as healpix nested, after interpolation it is ring ordering. We will now show how to get nested ordering back when interpolating healpix grids.

# %%
request = {
    "activity": "projections",
    'class': 'd1',
    'dataset': 'climate-dt',
    "date": "20400102",
    'time': "0000",
    'experiment': 'SSP3-7.0',
    'expver': '0001',
    "generation": "2",
    'levtype': 'sfc',
    'model': 'IFS-NEMO',
    'param': '167',
    'realization': '1',
    "resolution": "standard",
    'stream': 'clte',
    'grid':'hn16', # currently O, F, N, H grids are supported 
    'type': 'fc',
}

# %%
data_file = "../data/climate-dt-earthkit-healpix-interpolate.grib"
if LIVE_REQUEST:
    data = earthkit.data.from_source("polytope", "destination-earth", request, address="polytope.mn5.apps.dte.destination-earth.eu", stream=False)
    data.to_target("file", data_file)
else:
    data = earthkit.data.from_source("file", data_file)

# %%
df = data.to_fieldlist()
df.ls()

# %%
chart = earthkit.plots.Map(extent=[-180, 180, -90, 90])
chart.grid_cells(
    df,
    style="auto",
    units="celsius"
)

chart.title("Temperature")
chart.coastlines()
chart.gridlines()
chart.legend()
chart.show()
