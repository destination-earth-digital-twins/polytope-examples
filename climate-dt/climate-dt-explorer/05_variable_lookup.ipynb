# %% [markdown]
# # Variable Lookup — Climate DT Portfolio
#
# Search for a variable by **shortName** (e.g. `2t`, `avg_tos`) or by
# **keyword** in the long name (e.g. `temperature`, `wind`, `salinity`).
#
# The table shows which streams (monthly, hourly, storyline), level types,
# frequencies, models and resolutions are available.
#
# Use `access_snippet()` to get a ready-to-copy `from_climate_dt()` call.

# %%
from destine_portfolio import find_variable, access_snippet

# %% [markdown]
# ## Search by shortName

# %%
find_variable("2t")
# Out:
#   stream/activity shortName levtype     freq                  access  \
# 0            clte        2t     sfc   hourly              hourly/sfc
# 1       storyline        2t     sfc   hourly  hourly (storyline)/sfc
# 2            clmn    avg_2t     sfc  monthly             monthly/sfc
#
#                        long_name units                     models  \
# 0            2 metre temperature     K  IFS-NEMO, IFS-FESOM, ICON
# 1            2 metre temperature     K                  IFS-FESOM
# 2  Time-mean 2 metre temperature     K  IFS-NEMO, IFS-FESOM, ICON
#
#              experiments                            nside
# 0   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 1  cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 2   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}

# %%
# Ready-to-copy code for hourly 2t
access_snippet("2t", "clte")
# Out:
# ```python
# from polytope_zarr import PolytopeZarrStore
#
# store = PolytopeZarrStore.from_climate_dt(
#     models=["IFS-NEMO", "IFS-FESOM", "ICON"],
#     experiment="hist",
#     levtype="sfc",
#     frequency="hourly",
#     start_date="1990-01-01T00:00:00",
#     end_date="2014-12-31T23:00:00",
#     resolution="standard",
# )
#
# ds = store.open()
#
# import healpy as hp
# field = ds["2t"].sel(model="IFS-NEMO", time="1990-01-01T00:00")
# hp.mollview(field.values, title="IFS-NEMO — 2t — 1990-01-01T00:00",
#            unit="K", cmap="RdYlBu_r", nest=True, flip="geo")
# ```

# %%
# Ocean variable — note the different frequencies per stream
find_variable("thetao")
# Out:
#   stream/activity   shortName levtype     freq                  access  \
# 0            clmn  avg_thetao     o3d  monthly             monthly/o3d
# 1            clte  avg_thetao     o3d    daily              hourly/o3d
# 2       storyline  avg_thetao     o3d    daily  hourly (storyline)/o3d
#
#                                    long_name units                     models  \
# 0  Time-mean sea water potential temperature     K  IFS-NEMO, IFS-FESOM, ICON
# 1  Time-mean sea water potential temperature     K  IFS-NEMO, IFS-FESOM, ICON
# 2  Time-mean sea water potential temperature     K                  IFS-FESOM
#
#              experiments                            nside
# 0   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 1   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 2  cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}

# %%
access_snippet("avg_thetao", "clte")
# Out:
# ```python
# from polytope_zarr import PolytopeZarrStore
#
# store = PolytopeZarrStore.from_climate_dt(
#     models=["IFS-NEMO", "IFS-FESOM", "ICON"],
#     experiment="hist",
#     levtype="o3d",
#     frequency="hourly",
#     start_date="1990-01-01T00:00:00",
#     end_date="2014-12-31T23:00:00",
#     resolution="standard",
# )
#
# ds = store.open()
#
# import healpy as hp
# field = ds["avg_thetao"].sel(model="IFS-NEMO", time="1990-01-01T00:00", level=1)
# hp.mollview(field.values, title="IFS-NEMO — avg_thetao — 1990-01-01T00:00",
#            unit="K", cmap="RdYlBu_r", nest=True, flip="geo")
# ```

# %% [markdown]
# ## Search by keyword in long name

# %%
find_variable("temperature")
# Out:
#    stream/activity   shortName levtype     freq                  access  \
# 0             clte          2d     sfc   hourly              hourly/sfc
# 1        storyline          2d     sfc   hourly  hourly (storyline)/sfc
# 2             clte          2t     sfc   hourly              hourly/sfc
# 3        storyline          2t     sfc   hourly  hourly (storyline)/sfc
# 4             clmn      avg_2d     sfc  monthly             monthly/sfc
# 5             clmn      avg_2t     sfc  monthly             monthly/sfc
# 6             clmn     avg_skt     sfc  monthly             monthly/sfc
# 7             clmn       avg_t      pl  monthly              monthly/pl
# 8             clmn  avg_thetao     o3d  monthly             monthly/o3d
# 9             clte  avg_thetao     o3d    daily              hourly/o3d
# 10       storyline  avg_thetao     o3d    daily  hourly (storyline)/o3d
# 11            clmn     avg_tos     o2d  monthly             monthly/o2d
# 12            clte     avg_tos     o2d    daily              hourly/o2d
# 13       storyline     avg_tos     o2d    daily  hourly (storyline)/o2d
# 14            clte         skt     sfc   hourly              hourly/sfc
# 15       storyline         skt     sfc   hourly  hourly (storyline)/sfc
# 16       storyline         sot     sol   hourly  hourly (storyline)/sol
# 17            clte           t      pl   hourly               hourly/pl
# 18       storyline           t      pl   hourly   hourly (storyline)/pl
#
#                                     long_name units  \
# 0                2 metre dewpoint temperature     K
# 1                2 metre dewpoint temperature     K
# 2                         2 metre temperature     K
# 3                         2 metre temperature     K
# 4      Time-mean 2 metre dewpoint temperature     K
# 5               Time-mean 2 metre temperature     K
# 6                  Time-mean skin temperature     K
# 7                       Time-mean temperature     K
# 8   Time-mean sea water potential temperature     K
# 9   Time-mean sea water potential temperature     K
# 10  Time-mean sea water potential temperature     K
# 11          Time-mean sea surface temperature     K
# 12          Time-mean sea surface temperature     K
# 13          Time-mean sea surface temperature     K
# 14                           Skin temperature     K
# 15                           Skin temperature     K
# 16                           Soil temperature     K
# 17                                Temperature     K
# 18                                Temperature     K
#
#                        models            experiments  \
# 0   IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 1                   IFS-FESOM  cont, hist, Tplus2.0K
# 2   IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 3                   IFS-FESOM  cont, hist, Tplus2.0K
# 4   IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 5   IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 6   IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 7   IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 8   IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 9   IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 10                  IFS-FESOM  cont, hist, Tplus2.0K
# 11  IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 12  IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 13                  IFS-FESOM  cont, hist, Tplus2.0K
# 14  IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 15                  IFS-FESOM  cont, hist, Tplus2.0K
# 16                  IFS-FESOM  cont, hist, Tplus2.0K
# 17  IFS-NEMO, IFS-FESOM, ICON   cont, hist, SSP3-7.0
# 18                  IFS-FESOM  cont, hist, Tplus2.0K
#
#                               nside
# 0   {'standard': 128, 'high': 1024}
# 1    {'standard': 128, 'high': 512}
# 2   {'standard': 128, 'high': 1024}
# 3    {'standard': 128, 'high': 512}
# 4   {'standard': 128, 'high': 1024}
# 5   {'standard': 128, 'high': 1024}
# 6   {'standard': 128, 'high': 1024}
# 7   {'standard': 128, 'high': 1024}
# 8   {'standard': 128, 'high': 1024}
# 9   {'standard': 128, 'high': 1024}
# 10   {'standard': 128, 'high': 512}
# 11  {'standard': 128, 'high': 1024}
# 12  {'standard': 128, 'high': 1024}
# 13   {'standard': 128, 'high': 512}
# 14  {'standard': 128, 'high': 1024}
# 15   {'standard': 128, 'high': 512}
# 16   {'standard': 128, 'high': 512}
# 17  {'standard': 128, 'high': 1024}
# 18   {'standard': 128, 'high': 512}

# %%
find_variable("wind")
# Out:
#    stream/activity shortName levtype     freq                  access  \
# 0             clte      10si     sfc   hourly              hourly/sfc
# 1        storyline      10si     sfc   hourly  hourly (storyline)/sfc
# 2             clte       10u     sfc   hourly              hourly/sfc
# 3        storyline       10u     sfc   hourly  hourly (storyline)/sfc
# 4             clte       10v     sfc   hourly              hourly/sfc
# 5        storyline       10v     sfc   hourly  hourly (storyline)/sfc
# 6             clmn   avg_10u     sfc  monthly             monthly/sfc
# 7             clmn   avg_10v     sfc  monthly             monthly/sfc
# 8             clmn  avg_10ws     sfc  monthly             monthly/sfc
# 9             clmn     avg_u      hl  monthly              monthly/hl
# 10            clmn     avg_u      pl  monthly              monthly/pl
# 11            clmn     avg_v      hl  monthly              monthly/hl
# 12            clmn     avg_v      pl  monthly              monthly/pl
# 13            clte         u      hl   hourly               hourly/hl
# 14            clte         u      pl   hourly               hourly/pl
# 15       storyline         u      hl   hourly   hourly (storyline)/hl
# 16       storyline         u      pl   hourly   hourly (storyline)/pl
# 17            clte         v      hl   hourly               hourly/hl
# 18            clte         v      pl   hourly               hourly/pl
# 19       storyline         v      hl   hourly   hourly (storyline)/hl
# 20       storyline         v      pl   hourly   hourly (storyline)/pl
#
#                               long_name    units                     models  \
# 0                   10 metre wind speed  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 1                   10 metre wind speed  m s**-1                  IFS-FESOM
# 2             10 metre U wind component  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 3             10 metre U wind component  m s**-1                  IFS-FESOM
# 4             10 metre V wind component  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 5             10 metre V wind component  m s**-1                  IFS-FESOM
# 6   Time-mean 10 metre U wind component  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 7   Time-mean 10 metre V wind component  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 8         Time-mean 10 metre wind speed  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 9         Time-mean U component of wind  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 10        Time-mean U component of wind  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 11        Time-mean V component of wind  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 12        Time-mean V component of wind  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 13                  U component of wind  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 14                  U component of wind  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 15                  U component of wind  m s**-1                  IFS-FESOM
# 16                  U component of wind  m s**-1                  IFS-FESOM
# 17                  V component of wind  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 18                  V component of wind  m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 19                  V component of wind  m s**-1                  IFS-FESOM
# 20                  V component of wind  m s**-1                  IFS-FESOM
#
#               experiments                            nside
# 0    cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 1   cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 2    cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 3   cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 4    cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 5   cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 6    cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 7    cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 8    cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 9    cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 10   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 11   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 12   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 13   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 14   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 15  cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 16  cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 17   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 18   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 19  cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 20  cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}

# %%
access_snippet("u", "clte")
# Out:
# ```python
# from polytope_zarr import PolytopeZarrStore
#
# store = PolytopeZarrStore.from_climate_dt(
#     models=["IFS-NEMO", "IFS-FESOM", "ICON"],
#     experiment="hist",
#     levtype="pl",
#     frequency="hourly",
#     start_date="1990-01-01T00:00:00",
#     end_date="2014-12-31T23:00:00",
#     resolution="standard",
# )
#
# ds = store.open()
#
# import healpy as hp
# field = ds["u"].sel(model="IFS-NEMO", time="1990-01-01T00:00", level=1000)
# hp.mollview(field.values, title="IFS-NEMO — u — 1990-01-01T00:00",
#            unit="m s**-1", cmap="RdYlBu_r", nest=True, flip="geo")
# ```

# %%
find_variable("soil")
# Out:
#   stream/activity shortName levtype     freq                  access  \
# 0            clmn   avg_vsw     sol  monthly             monthly/sol
# 1       storyline       sot     sol   hourly  hourly (storyline)/sol
# 2            clte       vsw     sol   hourly              hourly/sol
# 3       storyline       vsw     sol   hourly  hourly (storyline)/sol
#
#                             long_name       units                     models  \
# 0  Time-mean volumetric soil moisture  m**3 m**-3  IFS-NEMO, IFS-FESOM, ICON
# 1                    Soil temperature           K                  IFS-FESOM
# 2            Volumetric soil moisture  m**3 m**-3  IFS-NEMO, IFS-FESOM, ICON
# 3            Volumetric soil moisture  m**3 m**-3                  IFS-FESOM
#
#              experiments                            nside
# 0   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 1  cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 2   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 3  cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}

# %%
access_snippet("vsw", "clte")
# Out:
# ```python
# from polytope_zarr import PolytopeZarrStore
#
# store = PolytopeZarrStore.from_climate_dt(
#     models=["IFS-NEMO", "IFS-FESOM", "ICON"],
#     experiment="hist",
#     levtype="sol",
#     frequency="hourly",
#     start_date="1990-01-01T00:00:00",
#     end_date="2014-12-31T23:00:00",
#     resolution="standard",
# )
#
# ds = store.open()
#
# import healpy as hp
# field = ds["vsw"].sel(model="IFS-NEMO", time="1990-01-01T00:00", level=1)
# hp.mollview(field.values, title="IFS-NEMO — vsw — 1990-01-01T00:00",
#            unit="m**3 m**-3", cmap="RdYlBu_r", nest=True, flip="geo")
# ```

# %%
access_snippet("sot", "storyline")
# Out:
# ```python
# from polytope_zarr import PolytopeZarrStore
#
# store = PolytopeZarrStore.from_climate_dt(
#     models=["IFS-FESOM"],
#     experiment=['cont', 'hist', 'Tplus2.0K'],
#     activity="story-nudging",
#     levtype="sol",
#     frequency="hourly",
#     start_date="2017-01-01T00:00:00",
#     end_date="2024-12-31T23:00:00",
#     resolution="standard",
# )
#
# ds = store.open()
#
# import healpy as hp
# field = ds["sot"].sel(climate="cont", time="2017-01-01T00:00", level=1)
# hp.mollview(field.values, title="cont — sot — 2017-01-01T00:00",
#            unit="K", cmap="RdYlBu_r", nest=True, flip="geo")
# ```

# %% [markdown]
# ## Full catalogue

# %%
find_variable()
# Out:
#     stream/activity shortName levtype    freq                  access  \
# 0              clte      10si     sfc  hourly              hourly/sfc
# 1         storyline      10si     sfc  hourly  hourly (storyline)/sfc
# 2              clte       10u     sfc  hourly              hourly/sfc
# 3         storyline       10u     sfc  hourly  hourly (storyline)/sfc
# 4              clte       10v     sfc  hourly              hourly/sfc
# ..              ...       ...     ...     ...                     ...
# 189       storyline       vsw     sol  hourly  hourly (storyline)/sol
# 190            clte         w      pl  hourly               hourly/pl
# 191       storyline         w      pl  hourly   hourly (storyline)/pl
# 192            clte         z      pl  hourly               hourly/pl
# 193       storyline         z      pl  hourly   hourly (storyline)/pl
#
#                      long_name       units                     models  \
# 0          10 metre wind speed     m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 1          10 metre wind speed     m s**-1                  IFS-FESOM
# 2    10 metre U wind component     m s**-1  IFS-NEMO, IFS-FESOM, ICON
# 3    10 metre U wind component     m s**-1                  IFS-FESOM
# 4    10 metre V wind component     m s**-1  IFS-NEMO, IFS-FESOM, ICON
# ..                         ...         ...                        ...
# 189   Volumetric soil moisture  m**3 m**-3                  IFS-FESOM
# 190          Vertical velocity    Pa s**-1  IFS-NEMO, IFS-FESOM, ICON
# 191          Vertical velocity    Pa s**-1                  IFS-FESOM
# 192               Geopotential  m**2 s**-2  IFS-NEMO, IFS-FESOM, ICON
# 193               Geopotential  m**2 s**-2                  IFS-FESOM
#
#                experiments                            nside
# 0     cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 1    cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 2     cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 3    cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 4     cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# ..                     ...                              ...
# 189  cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 190   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 191  cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
# 192   cont, hist, SSP3-7.0  {'standard': 128, 'high': 1024}
# 193  cont, hist, Tplus2.0K   {'standard': 128, 'high': 512}
#
# [194 rows x 10 columns]

# %% [markdown]
# ## Test the above snippets

# %%
import logging, warnings
import earthkit.data

# Disable earthkit disk cache (polytope_zarr caches decoded arrays in memory)
earthkit.data.config.set("cache-policy", "off")

# Silence verbose output from polytope / earthkit internals
for _ln in ("polytope", "polytope.api", "earthkit.data", "urllib3"):
    logging.getLogger(_ln).setLevel(logging.WARNING)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from polytope_zarr import PolytopeZarrStore

store = PolytopeZarrStore.from_climate_dt(
    models=["IFS-NEMO", "IFS-FESOM", "ICON"],
    experiment="hist",
    levtype="sfc",
    frequency="hourly",
    start_date="1990-01-01T00:00:00",
    end_date="2014-12-31T23:00:00",
    resolution="standard",
)

ds = store.open()

import healpy as hp
field = ds["2t"].sel(model="IFS-NEMO", time="1990-01-01T00:00")
hp.mollview(field.values, title="IFS-NEMO — 2t — 1990-01-01T00:00",
           unit="K", cmap="RdYlBu_r", nest=True, flip="geo")
# Out:
#   ⚡ batching 24 time chunks for 2t
# 2026-04-07 18:01:37 - INFO - Key read from /Users/natr/.polytopeapirc
# 2026-04-07 18:01:37 - INFO - Sending request...
# {'request': 'activity: baseline\n'
#             'class: d1\n'
#             'dataset: climate-dt\n'
#             "date: '19900101'\n"
#             'experiment: hist\n'
#             "expver: '0001'\n"
#             "generation: '2'\n"
#             'levtype: sfc\n'
#             'model: IFS-NEMO\n'
#             'param: 2t\n'
#             "realization: '1'\n"
#             'resolution: standard\n'
#             'stream: clte\n'
#             'time: '
#             '0000/0100/0200/0300/0400/0500/0600/0700/0800/0900/1000/1100/1200/1300/1400/1500/1600/1700/1800/1900/2000/2100/2200/2300\n'
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2026-04-07 18:01:37 - INFO - Polytope user key found in session cache for user natr
# 2026-04-07 18:01:38 - INFO - Request accepted. Please poll ./5ba22d29-ed2d-4b71-8cf0-fd717b90a574 for status
# 2026-04-07 18:01:38 - INFO - Polytope user key found in session cache for user natr
# 2026-04-07 18:01:38 - INFO - Checking request status (5ba22d29-ed2d-4b71-8cf0-fd717b90a574)...
# 2026-04-07 18:01:38 - INFO - The current status of the request is 'queued'
# 2026-04-07 18:01:39 - INFO - The current status of the request is 'processing'
# 2026-04-07 18:01:41 - INFO - The current status of the request is 'processed'

# %%
# circumventing the store to use earthkit's built-in caching and decoding
r = store.last_request
r["request"]
# Out:
# {'class': 'd1',
#  'dataset': 'climate-dt',
#  'type': 'fc',
#  'expver': '0001',
#  'generation': '2',
#  'realization': '1',
#  'activity': 'baseline',
#  'experiment': 'hist',
#  'levtype': 'sfc',
#  'resolution': 'standard',
#  'stream': 'clte',
#  'param': '2t',
#  'model': 'IFS-NEMO',
#  'date': '19900101',
#  'time': '0000/0100/0200/0300/0400/0500/0600/0700/0800/0900/1000/1100/1200/1300/1400/1500/1600/1700/1800/1900/2000/2100/2200/2300'}

# %%
data = earthkit.data.from_source("polytope", r["collection"], r["request"],
                                 address=r["address"], stream=False)
field = data.to_numpy()
field.shape
# Out:
# (24, 196608)

# %%
hp.mollview(field.mean(axis=0), title="IFS-NEMO — 2t — 1990-01-01T00:00",
           unit="K", cmap="RdYlBu_r", nest=True, flip="geo")

# %%
from polytope_zarr import PolytopeZarrStore

store = PolytopeZarrStore.from_climate_dt(
    models=["IFS-NEMO", "IFS-FESOM", "ICON"],
    experiment="hist",
    levtype="o2d",
    frequency="monthly",
    years=range(1990, 2015),
    resolution="standard",
)

ds = store.open()

import healpy as hp
field = ds["avg_tos"].sel(model="IFS-NEMO", time="1990-01-01")
hp.mollview(field.values, title="IFS-NEMO — avg_tos — 1990-01-01",
           unit="K", cmap="RdYlBu_r", nest=True, flip="geo")
# Out:
#   ⚡ batching 12 time chunks for avg_tos

# %%
from polytope_zarr import PolytopeZarrStore

store = PolytopeZarrStore.from_climate_dt(
    models=["IFS-NEMO", "IFS-FESOM", "ICON"],
    experiment="hist",
    levtype="o3d",
    frequency="hourly",
    start_date="1990-01-01T00:00:00",
    end_date="2014-12-31T23:00:00",
    resolution="standard",
)

ds = store.open()

import healpy as hp
field = ds["avg_thetao"].sel(model="IFS-NEMO", time="1990-01-01T00:00", level=1)
hp.mollview(field.values, title="IFS-NEMO — avg_thetao — 1990-01-01T00:00",
           unit="K", cmap="RdYlBu_r", nest=True, flip="geo")

# %%
from polytope_zarr import PolytopeZarrStore

store = PolytopeZarrStore.from_climate_dt(
    models=["IFS-NEMO", "IFS-FESOM", "ICON"],
    experiment="hist",
    levtype="pl",
    frequency="hourly",
    start_date="1990-01-01T00:00:00",
    end_date="2014-12-31T23:00:00",
    resolution="standard",
)

ds = store.open()

import healpy as hp
field = ds["u"].sel(model="IFS-NEMO", time="1990-01-01T00:00", level=1000)
hp.mollview(field.values, title="IFS-NEMO — u — 1990-01-01T00:00",
           unit="m s**-1", cmap="RdYlBu_r", nest=True, flip="geo")
# Out:
#   ⚡ batching 24 time chunks for u

# %%
from polytope_zarr import PolytopeZarrStore

store = PolytopeZarrStore.from_climate_dt(
    models=["IFS-NEMO", "IFS-FESOM", "ICON"],
    experiment="hist",
    levtype="sol",
    frequency="hourly",
    start_date="1990-01-01T00:00:00",
    end_date="2014-12-31T23:00:00",
    resolution="standard",
)

ds = store.open()

import healpy as hp
field = ds["vsw"].sel(model="IFS-NEMO", time="1990-01-01T00:00", level=1)
hp.mollview(field.values, title="IFS-NEMO — vsw — 1990-01-01T00:00",
           unit="m**3 m**-3", cmap="RdYlBu_r", nest=True, flip="geo")
# Out:
#   ⚡ batching 24 time chunks for vsw

# %%
from polytope_zarr import PolytopeZarrStore

store = PolytopeZarrStore.from_climate_dt(
    models=["IFS-FESOM"],
    experiment=['cont', 'hist', 'Tplus2.0K'],
    activity="story-nudging",
    levtype="sol",
    frequency="hourly",
    start_date="2017-01-01T00:00:00",
    end_date="2024-12-31T23:00:00",
    resolution="standard",
)

ds = store.open()

import healpy as hp
field = ds["sot"].sel(climate="cont", time="2017-01-01T00:00", level=1)
hp.mollview(field.values, title="IFS-FESOM — sot — 2017-01-01T00:00",
           unit="K", cmap="RdYlBu_r", nest=True, flip="geo")
# Out:
#   ⚡ batching 24 time chunks for sot
