# %% [markdown]
# ## Polytope Climate-DT Serverside Interpolation example notebook
#
# This notebook shows how to use earthkit-data and earthkit-plots to pull destination-earth data from LUMI and plot it using earthkit-plots. Specifically this notebook shows how to do server side interpolation to a supported grid and then retrieve a rectangular area.
#
# Before running the notebook you need to set up your credentials. See the main readme of this repository for different ways to do this or use the following cells to authenticate.
#
# You will need to generate your credentials using the desp-authentication.py script.
#
# This can be run as follows:

# %%
# %%capture cap
# %run ../desp-authentication.py

# %% [markdown]
# This will generate a token that can then be used by earthkit and polytope.

# %%
output_1 = cap.stdout.split('}\n')
access_token = output_1[-1][0:-1]

# %% [markdown]
# # Requirements
# To run this notebook install the following:
# * pip install earthkit-data
# * pip install earthkit-plots
# * pip install earthkit-regrid  (Optional for spectral variables)
# * pip install cf-units         (Optional for unit conversion in maps)
#
# If you do not have eccodes installed please install eccodes using conda as it is a dependency of earthkit, or install earthkit via conda
#
# * conda install eccodes -c conda-forge
# * conda install earthkit-data -c conda-forge

# %%
import earthkit.data
import earthkit.plots
import earthkit.regrid
from polytope.api import Client

# %%
# Set True if you want to make a live request for the data, or false if you want to use the cached grib file
LIVE_REQUEST = True

# %%
request = {
    'activity': 'scenariomip',
    'class': 'd1',
    'dataset': 'climate-dt',
    'date': '20300101',
    'time': "0000",
    'experiment': 'SSP3-7.0',
    'expver': '0001',
    'generation': '1',
    'levtype': 'sfc',
    'model': 'IFS-NEMO',
    'param': '167',
    'realization': '1',
    'resolution': 'high',
    'stream': 'clte',
    'grid' : 'O2560', # currently O, F, N grids are supported 
    'type': 'fc',
}

# %%
data_file = "data/climate-dt-earthkit-serverside-interpolation.grib"
if LIVE_REQUEST:
    data = earthkit.data.from_source("polytope", "destination-earth", request, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
    data.to_target("file", data_file)
else:
    data = earthkit.data.from_source("file", data_file)

# %%
data.ls()
# Out:
#   centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf        2t  heightAboveGround      2  20300101         0         0
#
#   dataType number    gridType
# 0       fc   None  reduced_gg

# %% [markdown]
# By default the interpolation method is linear and this can be specified with the `interpolation` key. The options available are `linera`, `bilinear`, `nearest neighbour`, and `nearest lsm`.

# %%
request2 = {
    'activity': 'scenariomip',
    'class': 'd1',
    'dataset': 'climate-dt',
    'date': '20300101',
    'time': "0000",
    'experiment': 'SSP3-7.0',
    'expver': '0001',
    'generation': '1',
    'levtype': 'sfc',
    'model': 'IFS-NEMO',
    'param': '167',
    'realization': '1',
    'resolution': 'high',
    'stream': 'clte',
    'grid' : 'O2560', # currently O, F, N grids are supported 
    'interpolation': 'bilinear',
    'type': 'fc',
}

# %%
data_file2 = "data/climate-dt-earthkit-serverside-interpolation2.grib"
if LIVE_REQUEST:
    data2 = earthkit.data.from_source("polytope", "destination-earth", request2, address="polytope.lumi.apps.dte.destination-earth.eu", stream=False)
    data2.to_target("file", data_file2)
else:
    data2 = earthkit.data.from_source("file", data_file2)

# %%
data2.ls()
# Out:
#   centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf        2t  heightAboveGround      2  20300101         0         0
#
#   dataType number    gridType
# 0       fc   None  reduced_gg
