# %% [markdown]
# # Solution 7: Post-Processing - Regridding and Interpolation
#
# In this exercise, you'll learn how to:
# - Use server-side interpolation to request data on different grids
# - Use client-side regridding with `earthkit.regrid`
# - Convert HEALPix data to regular lat-lon grids
# - Export data to different formats

# %% [markdown]
# ## Authentication

# %%
# %%capture cap
# %run ../../desp-authentication.py

# %%
output_1 = cap.stdout.split('}\n')
access_token = output_1[-1][0:-1]

# %% [markdown]
# ## Imports

# %%
import earthkit.data
import earthkit.plots
import earthkit.regrid
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Live Request Toggle

# %%
LIVE_REQUEST = os.getenv("LIVE_REQUEST", "true").lower() == "true"
LIVE_REQUEST

# %% [markdown]
# ## Part 1: Server-Side Interpolation
#
# The Climate DT stores data on a HEALPix grid. We can request server-side interpolation to get data on standard grids by adding a `grid` key to the request.
#
# Supported grid types:
# - `O` - Octahedral reduced Gaussian (e.g. `O1280`)
# - `F` - Regular Gaussian
# - `N` - Classic reduced Gaussian
# - `H` - HEALPix ring ordering
# - `HN` - HEALPix nested ordering

# %%
request_serverside = {
    "activity": "projections",
    "class": "d1",
    "dataset": "climate-dt",
    "date": "20400102",
    "time": "0000",
    "experiment": "SSP3-7.0",
    "expver": "0001",
    "generation": "2",
    "levtype": "sfc",
    "model": "IFS-NEMO",
    "param": "167",
    "realization": "1",
    "resolution": "standard",
    "stream": "clte",
    "type": "fc",
    "grid": "O1280",
    "interpolation": "linear",
}

# %% [markdown]
# ## Retrieve Server-Side Interpolated Data

# %%
data_file = "../../climate-dt/data/climate-dt-serverside-training.grib"

if LIVE_REQUEST:
    data_ss = earthkit.data.from_source(
        "polytope", "destination-earth", request_serverside,
        address="polytope.mn5.apps.dte.destination-earth.eu",
        stream=False,
    )
    data_ss.to_target("file", data_file)
else:
    data_ss = earthkit.data.from_source("file", data_file)

data_ss.ls()

# %% [markdown]
# ## Part 2: Client-Side Regridding
#
# Alternatively, we can retrieve data on its native grid and regrid locally using `earthkit.regrid`.
#
# First, let's get native HEALPix data:

# %%
request_native = {
    "activity": "projections",
    "class": "d1",
    "dataset": "climate-dt",
    "date": "20400102",
    "time": "0000",
    "experiment": "SSP3-7.0",
    "expver": "0001",
    "generation": "2",
    "levtype": "sfc",
    "model": "IFS-NEMO",
    "param": "167",
    "realization": "1",
    "resolution": "standard",
    "stream": "clte",
    "type": "fc",
}

data_file_native = "../../climate-dt/data/climate-dt-native-training.grib"

if LIVE_REQUEST:
    data_native = earthkit.data.from_source(
        "polytope", "destination-earth", request_native,
        address="polytope.mn5.apps.dte.destination-earth.eu",
        stream=False,
    )
    data_native.to_target("file", data_file_native)
else:
    data_native = earthkit.data.from_source("file", data_file_native)

data_native.ls()

# %% [markdown]
# ## Regrid to Regular Lat-Lon
#
# Regridding to a 0.5 x 0.5 degree regular grid.

# %%
out_grid = {"grid": [0.5, 0.5]}

data_regridded = earthkit.regrid.interpolate(
    data_native, 
    out_grid=out_grid, 
    method="linear"
)

print(f"Native fields: {len(data_native)}")
print(f"Regridded fields: {len(data_regridded)}")

# %% [markdown]
# ## Compare Native vs Regridded
#
# Let's plot both side by side.

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# Plot native (via earthkit.plots)
chart1 = earthkit.plots.Map(fig=fig, subplot_spec=axes[0])
chart1.grid_cells(data_native[0], auto_style=True)
chart1.coastlines()
chart1.title("Native HEALPix Grid")

# Plot regridded
chart2 = earthkit.plots.Map(fig=fig, subplot_spec=axes[1])
chart2.grid_cells(data_regridded[0], auto_style=True)
chart2.coastlines()
chart2.title("Regridded to 0.5\u00b0 Regular Lat-Lon")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 3: Convert to xarray
#
# Regridded data converts cleanly to xarray with proper lat/lon coordinates.

# %%
ds = data_regridded.to_xarray()
print(ds)

# Plot using xarray's built-in plotting
ds["2t"].isel(time=0).plot(figsize=(12, 5), cmap="RdYlBu_r")
plt.title("2m Temperature (regridded to 0.5\u00b0)")
plt.show()

# %% [markdown]
# ## Regrid Extremes DT Data
#
# The Extremes DT uses a reduced Gaussian grid (O2560). Here we regrid it to a regular 1x1 degree grid.

# %%
request_extremes = {
    "class": "d1",
    "dataset": "extremes-dt",
    "expver": "0001",
    "stream": "oper",
    "date": "-14",
    "time": "0000",
    "type": "fc",
    "levtype": "sfc",
    "step": "0",
    "param": "167",
}

data_file_extremes = "../../extremes-dt/data/extremes-dt-regrid-training.grib"

if LIVE_REQUEST:
    data_extremes = earthkit.data.from_source(
        "polytope", "destination-earth", request_extremes,
        address="polytope.lumi.apps.dte.destination-earth.eu",
        stream=False,
    )
    data_extremes.to_target("file", data_file_extremes)
else:
    data_extremes = earthkit.data.from_source("file", data_file_extremes)

# Regrid to 1x1 degree
data_extremes_regridded = earthkit.regrid.interpolate(
    data_extremes, out_grid={"grid": [1, 1]}, method="linear"
)

# Plot the regridded result
chart = earthkit.plots.Map()
chart.grid_cells(data_extremes_regridded[0], auto_style=True)
chart.coastlines()
chart.gridlines()
chart.title("Extremes DT - 2m Temperature (regridded to 1\u00b0)")
chart.show()
